# %%
#importing libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

data = pd.read_csv('./Flipkart_mobile_brands_data.csv')

# %%
data.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5        11990.0
#
#    Original Price
# 0         15990.0
# 1         15990.0
# 2         17990.0
# 3         17990.0
# 4         15990.0

# %%
# reading 'Rating' and plotting it in histogram with 20 intervals, title will be rating
data['Rating'].plot(kind='hist', bins=20, title='Rating')
plt.gca().spines[['top', 'right',]].set_visible(False) # this command is to remove border or despining

# %%
data['Selling Price'].plot(kind='hist', bins=20, title='Selling Price')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data['Brand'].groupby(data['Memory']).count().sort_values(ascending=False)
# Out:
# Memory
# 4 GB      631
# 3 GB      445
# 6 GB      381
# 2 GB      345
# 8 GB      264
# 1 GB      175
# 4GB       114
# 12 GB      45
# 4 MB       39
# 512 MB     33
# 1.5 GB     27
# 64 MB      16
# 16 MB      16
# 32 MB      14
# 8 MB       14
# 6GB        11
# 128 MB      6
# 768 MB      6
# 100 MB      3
# 10 MB       3
# 0.5 GB      2
# 256 MB      2
# 2 MB        2
# 46 MB       2
# 16 GB       2
# 717 MB      2
# 30 MB       1
# 32 GB       1
# 18 GB       1
# 153 MB      1
# 0 MB        1
# Name: Brand, dtype: int64

# %%
sns.pairplot(data, hue='Brand')
# Out:
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
sns.displot(data, x='Selling Price',bins=10, hue='Brand',aspect=1.2 )
# Out:
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax=sns.countplot(x="Brand", data=data )
# Out:
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
round(data.groupby('Brand')['Selling Price'].mean(),0).sort_values(ascending=False)
# Out:
# Brand
# Apple           78065.0
# Google Pixel    61392.0
# IQOO            37190.0
# SAMSUNG         23830.0
# HTC             23797.0
# vivo            23271.0
# LG              19323.0
# ASUS            18728.0
# OPPO            18677.0
# Motorola        16357.0
# Xiaomi          15540.0
# realme          15536.0
# POCO            12649.0
# Lenovo          10084.0
# Nokia            9251.0
# GIONEE           7135.0
# Name: Selling Price, dtype: float64

# %%
plt.figure(figsize=(9,7))
sns.scatterplot(data=data ,x='Rating', y='Selling Price',hue="Brand")
plt.show()
# Out:
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\chand\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# **Conclusion :-**
# The availability of Low Range Phones Should be Increased as most buyers buy phones in 15000 range
# Vivo is providing more rated products and are value for money.
# It is not true that only higher selling price products have a higher rating maximum mobiles lying between 0 to 25000 also have a good rating
